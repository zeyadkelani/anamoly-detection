# %% [markdown]
# ## Detecting Outliers in GES dataset
#
# ### Zeyad Kelani
# #### July 2019

# %%
# Load your libraries into working evnironment: 
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('ticks')
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\Zeyad Elkelani\\OneDrive - Claremont Graduate University\\github\\anamoly-detection'

# %%
#! pip install sklearn
from sklearn.ensemble import IsolationForest
from sklearn.covariance import EllipticEnvelope
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.svm import OneClassSVM
#from sklearn.neighbors import LocalOutlierFactor

# %%
os.chdir("C:\\Users\\Zeyad Elkelani\\OneDrive - Claremont Graduate University\\github\\anamoly-detection\\GES")

# %%
os.listdir('.')
# Out:
# ['first_cut.dta']

# %%
df = pd.read_stata('first_cut.dta')
df = df.fillna(0)

# %%
df[:6]
# Out:
#     deaths  injuries                     location  yield  density  bypass  \
# 0   4650.0   16270.0      Cairns, QLD Australia        5   1000.0     0.0
# 1   4550.0   15170.0  Killeen, TX United States        5   1000.0     0.0
# 2  18690.0   51910.0       Saint-Etienne France        5   1000.0     0.0
# 3  13400.0   24270.0     Erie, PA United States        5   1000.0     0.0
# 4  10090.0   21510.0              Lahti Finland        5   1000.0     0.0
# 5  10280.0   36990.0  Buffalo, NY United States        5   1000.0     0.0
#
#         average
# 0  36018.667969
# 1  36018.667969
# 2  36018.667969
# 3  36018.667969
# 4  36018.667969
# 5  36018.667969

# %%
#Select Data based on 100kt yield capacity
df_100 = df.loc[df['yield'] == 100]

# %%
df_100.describe()
# Out:
#              deaths      injuries  yield       density      bypass  \
# count  4.520000e+02  4.520000e+02  452.0    452.000000  452.000000
# mean   1.774523e+05  3.000702e+05  100.0   7995.575195    0.053097
# std    1.579127e+05  3.130495e+05    0.0   4316.212891    0.224476
# min    0.000000e+00  0.000000e+00  100.0   1000.000000    0.000000
# 25%    6.112750e+04  1.094450e+05  100.0   4000.000000    0.000000
# 50%    1.458350e+05  2.168700e+05  100.0   8000.000000    0.000000
# 75%    2.437200e+05  3.760075e+05  100.0  12000.000000    0.000000
# max    1.062430e+06  2.628350e+06  100.0  15000.000000    1.000000
#
#              average
# count     452.000000
# mean   472891.000000
# std    229290.859375
# min         0.000000
# 25%    253633.328125
# 50%    511491.656250
# 75%    614131.000000
# max    865174.812500

# %%
#Then subsset by different density levels
# groupby denisty_level
denisty_level = df_100.groupby("density")

# print product and corresponding product df
for density, density_df in denisty_level:
    print(density)
    print(density_df)

# %%
#get each group indivudally:
first_df = denisty_level.get_group(1000.0)
first_df.describe()
first_df.hist(figsize=(9,9));

# %%
# We only care about deaths here: 
first_df.boxplot(return_type='dict')
plt.plot
# Out:
# <function matplotlib.pyplot.plot>

# %% [markdown]
# #####  Functions for defining outliers From Kaggle:
# - We use made functions that Define two functions that statistically identify outliers in a pandas Series using a standard deviation and interquartile range method.
#     - https://www.kaggle.com/kevinarvai/outlier-detection-practice-uni-multivariate

# %%
def out_std(s, nstd=2.0, return_thresholds=False):
    """
    Return a boolean mask of outliers for a series
    using standard deviation, works column-wise.
    param nstd:
        Set number of standard deviations from the mean
        to consider an outlier
    :type nstd: ``float``
    param return_thresholds:
        True returns the lower and upper bounds, good for plotting.
        False returns the masked array 
    :type return_thresholds: ``bool``
    """
    data_mean, data_std = s.mean(), s.std()
    cut_off = data_std * nstd
    lower, upper = data_mean - cut_off, data_mean + cut_off
    if return_thresholds:
        return lower, upper
    else:
        return [True if x < lower or x > upper else False for x in s]
    ###
def out_iqr(s, k=1.5, return_thresholds=False):
    """
    Return a boolean mask of outliers for a series
    using interquartile range, works column-wise.
    param k:
        some cutoff to multiply by the iqr
    :type k: ``float``
    param return_thresholds:
        True returns the lower and upper bounds, good for plotting.
        False returns the masked array 
    :type return_thresholds: ``bool``
    """
    # calculate interquartile range
    q25, q75 = np.percentile(s, 25), np.percentile(s, 75)
    iqr = q75 - q25
    # calculate the outlier cutoff
    cut_off = iqr * k
    lower, upper = q25 - cut_off, q75 + cut_off
    if return_thresholds:
        return lower, upper
    else: # identify outliers
        return [True if x < lower or x > upper else False for x in s]

# %%
# outlier_mask is a boolean list identifies the indices of the outliers
outlier_mask = out_std(first_df['deaths'], nstd=2.0)
# first 10 elements
outlier_mask[:10]
# Out:
# [False, False, False, False, False, False, False, False, False, False]

# %%
print(first_df['deaths'][outlier_mask])
# Out:
# 4089     88900.0
# 4096    100700.0
# Name: deaths, dtype: float64

# %%
first_df.insert(2, "outlier_mask", outlier_mask)

# %%
def plot_cutoff(dataframe, col, nstd=2.0, color='red'):
    """
    Version 8 update: more generic function.
    Function added in Version 6, more readable code than previous versions.
    From version 4 update: 
    This code block will plot lower and upper thresholds.
    I'm still thinking about how to best visualize this, suggestions welcome!
    """
    lower, upper = out_std(dataframe[col], nstd=nstd, return_thresholds=True)
    plt.axvspan(min(dataframe[col][dataframe[col] < lower], default=dataframe[col].min()), lower, alpha=0.2, color=color);
    plt.axvspan(upper, max(dataframe[col][dataframe[col] > upper], default=dataframe[col].max()), alpha=0.2, color=color);

# %%
column = 'deaths'
sns.distplot(first_df[column], kde=False)
plot_cutoff(first_df, column, nstd=2.0, color='red');
plot_cutoff(first_df, column, nstd=3.0, color='green');
plot_cutoff(first_df, column, nstd=4.0, color='yellow');

# %%
first_df
# Out:
#         deaths  injuries  outlier_mask                          location  \
# 4068   43800.0   68110.0         False      Fargo, ND-MN United States
# 4069   35830.0   39720.0         False                   Lahti Finland
# 4070   30740.0   43180.0         False       Medford, OR United States
# 4071   18440.0   28760.0         False              Nanaimo, BC Canada
# 4072   14840.0   46150.0         False   Victorville, CA United States
# 4073   23020.0  158540.0         False          Arabia Ad-Dammam Saudi
# 4074   29750.0   52180.0         False         Indio, CA United States
# 4075   46550.0   50860.0         False   Bloomington, IN United States
# 4076   30950.0   38640.0         False         Peterborough, ON Canada
# 4077   35550.0   69960.0         False  Fort Collins, CO United States
# 4078   33050.0   45180.0         False        Norman, OK United States
# 4079   26730.0   43040.0         False           Cairns, QLD Australia
# 4080   33140.0   43760.0         False     St. Cloud, MN United States
# 4081   14160.0   39230.0         False               Kelowna,BC Canada
# 4082   72930.0  147010.0         False     Rochester, NY United States
# 4083   54920.0  114740.0         False       St. Louis, MO United States
# 4084   21410.0   29480.0         False        Kailua, HI United States
# 4085   82560.0   96800.0         False            Saint-Etienne France
# 4086   51780.0   69410.0         False                Dunkerque France
# 4087   67090.0  116930.0         False     Cleveland, OH United States
# 4088   39710.0   54440.0         False               Barrie, ON Canada
# 4089   88900.0  182620.0          True       Detroit, MI United States
# 4090   44360.0   63770.0         False          Erie, PA United States
# 4091   25990.0   53960.0         False       Killeen, TX United States
# 4092   51280.0   84330.0         False        Eugene, OR United States
# 4093   33130.0   48450.0         False       Greeley, CO United States
# 4094   46790.0  180240.0         False   Brownsville, TX United States
# 4095   65350.0  156040.0         False       Buffalo, NY United States
# 4096  100700.0  129490.0          True                 Grenoble France
# 4097   54500.0  100190.0         False       Reno, NV-CA United States
#
#       yield  density  bypass   average
# 4068    100   1000.0     0.0  123772.0
# 4069    100   1000.0     0.0  123772.0
# 4070    100   1000.0     0.0  123772.0
# 4071    100   1000.0     0.0  123772.0
# 4072    100   1000.0     0.0  123772.0
# 4073    100   1000.0     0.0  123772.0
# 4074    100   1000.0     0.0  123772.0
# 4075    100   1000.0     0.0  123772.0
# 4076    100   1000.0     0.0  123772.0
# 4077    100   1000.0     0.0  123772.0
# 4078    100   1000.0     0.0  123772.0
# 4079    100   1000.0     0.0  123772.0
# 4080    100   1000.0     0.0  123772.0
# 4081    100   1000.0     0.0  123772.0
# 4082    100   1000.0     0.0  123772.0
# 4083    100   1000.0     0.0  123772.0
# 4084    100   1000.0     0.0  123772.0
# 4085    100   1000.0     0.0  123772.0
# 4086    100   1000.0     0.0  123772.0
# 4087    100   1000.0     0.0  123772.0
# 4088    100   1000.0     0.0  123772.0
# 4089    100   1000.0     0.0  123772.0
# 4090    100   1000.0     0.0  123772.0
# 4091    100   1000.0     0.0  123772.0
# 4092    100   1000.0     0.0  123772.0
# 4093    100   1000.0     0.0  123772.0
# 4094    100   1000.0     0.0  123772.0
# 4095    100   1000.0     0.0  123772.0
# 4096    100   1000.0     0.0  123772.0
# 4097    100   1000.0     0.0  123772.0
